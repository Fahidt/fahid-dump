# %%
load_ext sql

# %%
sql mysql+pymysql://root:PASSWORD!@localhost:3306/rice

# %%
result = %sql SELECT * FROM rice_t
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rice
# 88 rows affected.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 7))
result = %sql SELECT name_,sum(cost) from rice_t group by name_
labels = []
values = []
for row in result:
    labels.append(row[0])
    values.append(row[1])
plt.pie(x = values, labels = labels)
plt.show()
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rice
# 9 rows affected.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 7))
result = %sql SELECT name_, cost from rice_t group by name_
labels = []
values = []
for row in result:
    labels.append(row[0])
    values.append(row[1])

    
print(labels)   
print(values)
# explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
# fig1, ax1 = plt.subplots()
# ax1.pie(values, explode=explode, labels=labels, autopct='%1.1f%%',
#         shadow=True, startangle=90)
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# plt.show()

# https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rice
# 9 rows affected.
# ['Abdul', 'Musti', 'Gure', 'Hamma', 'Tango', 'Hanif', 'Fahid', 'Isse', 'Sherif']
# [6, 5, 6, 6, 5, 6, 6, 5, 5]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

result = %sql SELECT name_,sum(cost) from rice_t group by name_
labels = []
values = []
for row in result:
    labels.append(row[0])
    values.append(row[1])
    
plt.style.use('ggplot')

# x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
# energy = [5, 6, 15, 22, 24, 8]

x_pos = [i for i, _ in enumerate(labels)]

plt.bar(x_pos, values, color='green')
plt.xlabel("Customer")
plt.ylabel("Total spend (£)")
plt.title("Customer spend chart")

plt.xticks(x_pos, labels)

plt.show()
# Out:
#  * mysql+pymysql://root:***@localhost:3306/rice
# 9 rows affected.
